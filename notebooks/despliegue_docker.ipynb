# %% [markdown]
# # Despliegue Docker de la API de Predicción de Rendimiento Estudiantil
# **Autor:** Luis Felipe Neri Alvarado
#
# ## Introducción
# ---
# En este notebook vamos a preparar y desplegar una API de predicción de rendimiento estudiantil
# construida con FastAPI y un modelo de Machine Learning. El objetivo es containerizar la aplicación en
# Docker para facilitar su despliegue.
#
# Seguiremos estos pasos:
#
#
# -Clonar el repositorio desde GitHub que contiene el código de la API y el modelo entrenado.
#
# -Instalar las dependencias necesarias (FastAPI, Uvicorn, scikit-learn, etc.).
# Probar la API localmente en el entorno de Colab para verificar que funciona correctamente.
#
# -Crear un Dockerfile para definir la imagen de Docker con la aplicación.
#
# -Construir la imagen Docker a partir del Dockerfile.
#
# -Ejecutar el contenedor Docker y verificar que la API funcione dentro del contenedor.
#
# -Realizar pruebas a la API corriendo en el contenedor (endpoints de salud y predicción).
#
# **Nota**: Google Colab (entorno gratuito) no permite ejecutar Docker de forma nativa
# debido a restricciones de privilegios a nivel de kernel. Como solución alternativa,
# usaremos udocker , una herramienta que permite ejecutar contenedores Docker en
# espacio de usuario sin privilegios de root . De todas formas, mostraremos también los comandos estándar de Docker para entornos locales.

# %% [markdown]
# ## Montaje de repositorio
# -- Clonamos el repositorio a través de una key de github

# %%
from getpass import getpass

GITHUB_TOKEN = getpass("Token GitHub: ")
# Out:
# Token GitHub: ··········

# %%
# Clonar el repositorio de GitHub (reemplaza con tus credenciales si es privado)
GITHUB_USER = "TuUsuarioGitHub"        # <--- Cambia esto
REPO_OWNER  = "gerv94"
REPO_NAME   = "proyecto_mlops_equipo_56"
BRANCH      = "main"

# Construir la URL remota (usa autenticación si TOKEN está disponible)
if GITHUB_TOKEN and GITHUB_USER:
    remote_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{REPO_OWNER}/{REPO_NAME}.git"
else:
    remote_url = f"https://github.com/{REPO_OWNER}/{REPO_NAME}.git"

# Ruta local de clonación
LOCAL_REPO = "/content/proyecto_mlops_equipo_56"

# Eliminar carpeta previa si existe para empezar limpio
import shutil, os
if os.path.exists(LOCAL_REPO):
    shutil.rmtree(LOCAL_REPO)

# !git clone -b $BRANCH $remote_url $LOCAL_REPO

# Cambiar directorio de trabajo al repositorio clonado
# %cd $LOCAL_REPO
# Out:
# Cloning into '/content/proyecto_mlops_equipo_56'...
# remote: Enumerating objects: 3444, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 3444 (delta 41), reused 62 (delta 25), pack-reused 3349 (from 1)
# Receiving objects: 100% (3444/3444), 12.79 MiB | 1.85 MiB/s, done.
# Resolving deltas: 100% (1041/1041), done.
# /content/proyecto_mlops_equipo_56

# %%
## Instalación de dependencias

# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.3.5)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: scipy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (1.16.3)
# Collecting scikit-learn==1.5.2 (from -r requirements.txt (line 16))
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (3.6.0)
# Requirement already satisfied: xgboost>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (3.1.1)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (3.10.0)
# Requirement already satisfied: seaborn>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (5.24.1)
# Requirement already satisfied: mlflow==3.5.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 31)) (3.5.1)
# Requirement already satisfied: cloudpickle==3.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 32)) (3.1.0)
# Requirement already satisfied: pyarrow==18.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (18.1.0)
# Requirement already satisfied: dvc==3.55.2 in /usr/local/lib/python3.12/dist-packages (from dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.55.2)
# Requirement already satisfied: python-dotenv==1.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 39)) (1.0.1)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 40)) (6.0.2)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 41)) (24.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 42)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 43)) (2024.2)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 44)) (2025.2)
# Requirement already satisfied: Flask==3.1.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 49)) (3.1.2)
# Requirement already satisfied: waitress==3.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 50)) (3.0.2)
# Requirement already satisfied: SQLAlchemy==2.0.44 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 51)) (2.0.44)
# Requirement already satisfied: alembic==1.17.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 52)) (1.17.1)
# Requirement already satisfied: setuptools==70.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 57)) (70.3.0)
# Requirement already satisfied: wheel==0.44.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 58)) (0.44.0)
# Requirement already satisfied: rich==13.9.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 63)) (13.9.2)
# Requirement already satisfied: psutil==6.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 64)) (6.1.0)
# Requirement already satisfied: pytest>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 69)) (8.4.2)
# Requirement already satisfied: pytest-cov>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 70)) (7.0.0)
# Requirement already satisfied: fastapi==0.115.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 75)) (0.115.6)
# Requirement already satisfied: uvicorn==0.32.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (0.32.0)
# Requirement already satisfied: pydantic==2.9.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 77)) (2.9.2)
# Requirement already satisfied: mlflow-skinny==3.5.1 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (3.5.1)
# Requirement already satisfied: mlflow-tracing==3.5.1 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (3.5.1)
# Requirement already satisfied: Flask-CORS<7 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (6.0.1)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (43.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.12/dist-packages (from mlflow==3.5.1->-r requirements.txt (line 31)) (23.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (25.4.0)
# Requirement already satisfied: celery in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.5.3)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.4.6)
# Requirement already satisfied: configobj>=5.0.6 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.0.9)
# Requirement already satisfied: distro>=1.3 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.2.0)
# Requirement already satisfied: dulwich in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.24.10)
# Requirement already satisfied: dvc-data<3.17,>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.16.12)
# Requirement already satisfied: dvc-http>=2.29.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.32.0)
# Requirement already satisfied: dvc-objects in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.1.2)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.40.2)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: flufl.lock<9,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (8.2.0)
# Requirement already satisfied: fsspec>=2024.2.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2025.3.0)
# Requirement already satisfied: funcy>=1.14 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.0.10)
# Requirement already satisfied: kombu in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.5.4)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.5)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.3.0)
# Requirement already satisfied: pathspec>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.12.1)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.11.0)
# Requirement already satisfied: pydot>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.0.4)
# Requirement already satisfied: pygtrie>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.2.5)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.32.4)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.18.16)
# Requirement already satisfied: scmrepo<4,>=3.3.4 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.5.4)
# Requirement already satisfied: shortuuid>=0.5 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.7.2)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.13.3)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (4.67.1)
# Requirement already satisfied: voluptuous>=0.11.7 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.15.2)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil==2.9.0.post0->-r requirements.txt (line 42)) (1.17.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask==3.1.2->-r requirements.txt (line 49)) (3.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy==2.0.44->-r requirements.txt (line 51)) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy==2.0.44->-r requirements.txt (line 51)) (4.15.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic==1.17.1->-r requirements.txt (line 52)) (1.3.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich==13.9.2->-r requirements.txt (line 63)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich==13.9.2->-r requirements.txt (line 63)) (2.19.2)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.115.6->-r requirements.txt (line 75)) (0.41.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn==0.32.0->uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.9.2->-r requirements.txt (line 77)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.12/dist-packages (from pydantic==2.9.2->-r requirements.txt (line 77)) (2.23.4)
# Requirement already satisfied: dvc-s3<4,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.2.2)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (0.7.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]==0.32.0->-r requirements.txt (line 76)) (15.0.1)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (5.5.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (0.73.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (1.37.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (5.29.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (0.5.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=2.0.0->-r requirements.txt (line 19)) (2.27.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 24)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 24)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 24)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 24)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 24)) (11.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->-r requirements.txt (line 26)) (8.5.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0.0->-r requirements.txt (line 69)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0.0->-r requirements.txt (line 69)) (1.6.0)
# Requirement already satisfied: coverage>=7.10.6 in /usr/local/lib/python3.12/dist-packages (from coverage[toml]>=7.10.6->pytest-cov>=4.1.0->-r requirements.txt (line 70)) (7.11.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<47,>=43.0.0->mlflow==3.5.1->-r requirements.txt (line 31)) (2.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker<8,>=4.0.0->mlflow==3.5.1->-r requirements.txt (line 31)) (2.5.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.17,>=3.16.2->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.17,>=3.16.2->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.17,>=3.16.2->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.17,>=3.16.2->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.11.4)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from dvc-http>=2.29.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.9.1)
# Requirement already satisfied: s3fs>=2024.12.0 in /usr/local/lib/python3.12/dist-packages (from dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2025.3.0)
# Requirement already satisfied: aiobotocore>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.25.2)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (4.2.3)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.1.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.1.1.2)
# Requirement already satisfied: atpublic in /usr/local/lib/python3.12/dist-packages (from flufl.lock<9,>=8.1.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow==3.5.1->-r requirements.txt (line 31)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.12/dist-packages (from graphene<4->mlflow==3.5.1->-r requirements.txt (line 31)) (3.2.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.4)
# Requirement already satisfied: pydantic-settings>=2 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.12.0)
# Requirement already satisfied: semver>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.20.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.1->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (4.9.3)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.12/dist-packages (from iterative-telemetry>=0.0.7->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from iterative-telemetry>=0.0.7->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.20.0)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from kombu->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (5.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich==13.9.2->-r requirements.txt (line 63)) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2025.10.5)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml>=0.17.11->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.2.15)
# Requirement already satisfied: pygit2>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from scmrepo<4,>=3.3.4->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.19.0)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /usr/local/lib/python3.12/dist-packages (from scmrepo<4,>=3.3.4->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.21.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi==0.115.6->-r requirements.txt (line 75)) (4.11.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.13.0)
# Requirement already satisfied: botocore<1.40.71,>=1.40.46 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.40.70)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.17.3)
# Requirement already satisfied: boto3<1.40.71,>=1.40.46 in /usr/local/lib/python3.12/dist-packages (from aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.40.70)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi==0.115.6->-r requirements.txt (line 75)) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow==3.5.1->-r requirements.txt (line 31)) (2.23)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /usr/local/lib/python3.12/dist-packages (from click-repl>=0.2.0->celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (3.0.52)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (0.58b0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2->gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore>=2.5.0->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (1.22.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3<1.40.71,>=1.40.46->aiobotocore[boto3]>=2.5.0->dvc-s3<4,>=3.2.0->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.14.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (4.9.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc==3.55.2->dvc[S3]==3.55.2->-r requirements.txt (line 34)) (0.2.14)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1->-r requirements.txt (line 31)) (0.6.1)
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 89.7 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2

# %%
# Reiniciar el entorno
import os
os.kill(os.getpid(), 9)

# Verificación de dependencias relevantes:

import importlib

packages = ["fastapi", "uvicorn", "pandas", "sklearn", "joblib"]

for pkg in packages:
    try:
        importlib.import_module(pkg)
        print(f"{pkg}: OK — instalado")
    except ImportError:
        print(f"{pkg}: NO INSTALADO")
# Out:
# fastapi: OK — instalado
# uvicorn: OK — instalado
# pandas: OK — instalado
# sklearn: OK — instalado
# joblib: OK — instalado

# %% [markdown]
# ## 2.1 Ejecución de modelo debido a problemas con DVC
# ---
#
# Debido a problemas con el DVC se optó por realizar una ejecución local para generar un modelo que pudieramos probar en el entorno.

# %%
import os
os.chdir("/content/proyecto_mlops_equipo_56")  # Ajusta si tu ruta local es diferente
# !pwd  # Esto confirmará en qué carpeta estás parado
# Out:
# /content/proyecto_mlops_equipo_56

# %%
# !python -m mlops.run_preprocess

# %%
# !python train/train_gridsearch.py
# Out:
# 2025/11/17 19:50:12 INFO mlflow.tracking.fluent: Experiment with name 'student_performance_gridsearch_amplio' does not exist. Creating a new experiment.
#
# ======================================================================
# GRID SEARCH FINO - BÚSQUEDA CERCANA AL MODELO BASE
# ======================================================================
# Modelo base: n_estimators=20, max_depth=20, min_samples_split=15
# Random state modelo: 888
#
# Rangos de búsqueda:
#   n_estimators: [18, 20, 22, 25]
#   max_depth: [18, 20, 22]
#   min_samples_split: [12, 15, 18]
#   min_samples_leaf: [1, 2]
#   max_features: ['sqrt', 'log2']
#
# Total de combinaciones: 144
# Tiempo estimado: ~15-20 minutos
# CV folds: 5
# Métrica principal: f1_weighted
# Preprocessing: OneHotEncoder (remainder='drop')
# ======================================================================
#
# Iniciando búsqueda... (esto puede tomar varios minutos)
#
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=20; total time=   0.3s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=20; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=20; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=20; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=22; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=22; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=22; total time=   0.3s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=22; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=25; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=25; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=25; total time=   0.2s
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=12, classifier__n_estimators=25; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=18; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=15, classifier__n_estimators=25; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=18, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=18; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=20; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.2s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=22; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=25; total time=   0.1s
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=25; total time=   0.1s
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=25; total time=   0.1s
# [CV] END classifier__class_weight=None, classifier__criterion=gini, classifier__max_depth=22, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=18, classifier__n_estimators=25; total time=   0.1s
#
# ======================================================================
# GRID SEARCH COMPLETADO
# ======================================================================
# Mejor CV F1-Weighted: 0.5355
#
# Mejores parámetros:
#   class_weight: None
#   criterion: gini
#   max_depth: 22
#   max_features: sqrt
#   min_samples_leaf: 1
#   min_samples_split: 15
#   n_estimators: 20
# ======================================================================
#
# Registrando top 10 modelos en MLflow...
#
#
# ======================================================================
# *** MEJOR MODELO (Rank 1) ***
# ======================================================================
# CV F1-Weighted: 0.5355 ± 0.0368
# Test Accuracy:  0.5368
# Test F1-Weighted: 0.5182
# Test F1-Macro:    0.3859
#
# Parámetros:
#   class_weight: None
#   criterion: gini
#   max_depth: 22
#   max_features: sqrt
#   min_samples_leaf: 1
#   min_samples_split: 15
#   n_estimators: 20
# ======================================================================
#
# 2025/11/17 19:51:27 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/17 19:51:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Rank 2: CV F1=0.5344, Test Acc=0.5368, Test F1=0.5182
# Rank 3: CV F1=0.5311, Test Acc=0.5147, Test F1=0.4985
# Rank 4: CV F1=0.5308, Test Acc=0.5294, Test F1=0.5117
# Rank 5: CV F1=0.5296, Test Acc=0.5441, Test F1=0.5299
# Rank 6: CV F1=0.5285, Test Acc=0.5441, Test F1=0.5299
# Rank 7: CV F1=0.5277, Test Acc=0.5147, Test F1=0.4987
# Rank 8: CV F1=0.5277, Test Acc=0.5294, Test F1=0.5117
# Rank 9: CV F1=0.5276, Test Acc=0.5221, Test F1=0.5084
# Rank 10: CV F1=0.5241, Test Acc=0.5147, Test F1=0.4964
#
# Top 10 modelos registrados en MLflow.
#
# ======================================================================
# GRID SEARCH FINALIZADO
# Revisa MLflow UI para comparar todos los modelos
# Experimento: student_performance_gridsearch_amplio
# ======================================================================

# %% [markdown]
# ## 3. Prueba local de la API en Colab
#
# Antes de generar la imagen Docker, es recomendable verificar que la API
# funciona correctamente ejecutándola directamente en el entorno actual.
# Para esto levantaremos la aplicación FastAPI utilizando Uvicorn.
#
# La aplicación está definida en el archivo app_api.py, el cual:
#
# -   Carga el modelo al iniciar
# -   Expone la instancia app utilizada por FastAPI
# -   Define los endpoints necesarios
#
# Para lanzar el servidor sin bloquear la ejecución del notebook,
# usaremos:
#
# -   & para enviarlo al segundo plano
# -   nohup para que continúe corriendo aunque termine la celda
# -   Redirección de logs hacia un archivo server.log

# %% [markdown]
# ------------------------------------------------------------------------
#
# Ejecutar el servidor FastAPI

# %%
os.chdir("/content/proyecto_mlops_equipo_56")  # Ajusta si tu ruta local es diferente
# !pwd  # Esto confirmará en qué carpeta estás parado
# Out:
# /content/proyecto_mlops_equipo_56

# %%
# !nohup uvicorn app_api:app --host 0.0.0.0 --port 8000 &> server.log &

# %% [markdown]
# ------------------------------------------------------------------------
#
# Revisar si el servidor inició correctamente

# %%
# !head server.log
# Out:
# 2025-11-17 19:52:24,301 - app_api - INFO - Modelo cargado exitosamente desde models/best_gridsearch_amplio.joblib
# INFO:     Started server process [9299]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)

# %%
# Consulta al endpoint
import requests

try:
    resp = requests.get("http://localhost:8000/")
    print("Código de estado:", resp.status_code)
    print("Respuesta JSON:", resp.json())
except Exception as e:
    print("Error al conectar con la API:", e)
# Out:
# Código de estado: 200
# Respuesta JSON: {'message': 'Student Performance Prediction API', 'status': 'running', 'model_loaded': True, 'version': '1.0.0'}

# %%
# Endpoint health
resp = requests.get("http://localhost:8000/health")
print("Código de estado:", resp.status_code)
print("Respuesta JSON:", resp.json())
# Out:
# Código de estado: 200
# Respuesta JSON: {'status': 'healthy', 'model_loaded': True, 'model_path': 'models/best_gridsearch_amplio.joblib', 'timestamp': '2025-11-17T19:54:06.204759'}

# %%
# Prueba de predicción:
# ----------------------------------------
# Ejemplo de estudiante para predicción
sample_student = {
    "Gender": "Male",
    "Caste": "General",
    "coaching": "yes",
    "time": "3-4 hours",
    "Class_ten_education": "CBSE",
    "twelve_education": "CBSE",
    "medium": "English",
    "Class_X_Percentage": "vg",
    "Class_XII_Percentage": "vg",
    "Father_occupation": "Business",
    "Mother_occupation": "Housewife"
}

resp = requests.post("http://localhost:8000/predict", json={"students": [sample_student]})
print("Código de estado:", resp.status_code)
print("Respuesta JSON:", resp.json())
# Out:
# Código de estado: 200
# Respuesta JSON: {'predictions': [{'prediction': 'average', 'probability': 0.5274904599520966, 'all_probabilities': {'average': 0.5274904599520966, 'excellent': 0.0442334470019892, 'good': 0.2612122457678724, 'none': 0.0, 'vg': 0.16706384727804163}}], 'total_students': 1, 'timestamp': '2025-11-17T19:57:42.838606'}

# %%
# Liberación de puerto posterior a pruebas
# !kill $(pgrep uvicorn)

# %% [markdown]
# ##4 Creación del Dockertfile
# ---
# la API funciona correctamente en el entorno actual. Ahora procederemos a encapsular esta aplicación dentro de un contenedor Docker.
#
# ### Containerización con Docker
#
# Para containerizar la aplicación, escribiremos un `Dockerfile` que especifique cómo construir la imagen de Docker. Los pasos típicos en nuestro caso serán:
#
# 1. **Usar una imagen base de Python**
#    Por ejemplo, `python:3.10-slim`, una opción liviana y común para este tipo de aplicaciones.
#
# 2. **Copiar el código fuente**
#    Copiar todo el contenido del repositorio al sistema de archivos de la imagen.
#
# 3. **Instalar las dependencias**
#    Se puede usar un archivo `requirements.txt` con `pip install -r requirements.txt`, o instalarlas directamente desde el `Dockerfile`.
#
# 4. **Exponer el puerto 8000**
#    Es el puerto donde nuestra API de FastAPI estará sirviendo solicitudes.
#
# 5. **Definir el comando de arranque**
#    Usualmente usando Uvicorn, por ejemplo:
#    ```bash
#    uvicorn app_api:app --host 0.0.0.0 --port 8000
#    ```
#
# Este proceso garantiza que la aplicación pueda ejecutarse en cualquier entorno compatible con Docker, manteniendo la portabilidad y reproducibilidad del sistema.

# %%
# Creación del archivo Dockerfile en el directorio del repositorio:
# ----------------------------------------------------------------

# %%bash
cat > Dockerfile <<'EOF'
# Base image con Python 3.10 (slim para menor tamaño)
FROM python:3.12.6-slim

# Establecer directorio de trabajo dentro del contenedor
WORKDIR /app

# Copiar archivos de requerimientos e instalarlos (si existiera requirements.txt)
# COPY requirements.txt .
# RUN pip install -r requirements.txt

# Instalar dependencias directamente (alternativa si no hay requirements.txt)
RUN pip install fastapi uvicorn pandas scikit-learn joblib

# Copiar todo el código de la aplicación al directorio de trabajo
COPY . /app

# Exponer el puerto 8000 para la API
EXPOSE 8000

# Comando por defecto para lanzar la aplicación con Uvicorn
# Se utiliza 'uvicorn app_api:app' (app_api es el nombre del archivo, app es la instancia de FastAPI)
CMD ["uvicorn", "app_api:app", "--host", "0.0.0.0", "--port", "8000"]
EOF

# %%
# Validar contenido del dockerfile

# !sed -n '1,20p' Dockerfile  # mostrar las primeras 20 líneas del Dockerfile
# Out:
# # Base image con Python 3.10 (slim para menor tamaño)
# FROM python:3.12.6-slim
#
# # Establecer directorio de trabajo dentro del contenedor
# WORKDIR /app
#
# # Copiar archivos de requerimientos e instalarlos (si existiera requirements.txt)
# # COPY requirements.txt .
# # RUN pip install -r requirements.txt
#
# # Instalar dependencias directamente (alternativa si no hay requirements.txt)
# RUN pip install fastapi uvicorn pandas scikit-learn joblib
#
# # Copiar todo el código de la aplicación al directorio de trabajo
# COPY . /app
#
# # Exponer el puerto 8000 para la API
# EXPOSE 8000
#
# # Comando por defecto para lanzar la aplicación con Uvicorn

# %% [markdown]
# ### Explicación del Dockerfile:
#
# *	**FROM python:3.12.6-slim**: Usa la imagen oficial de Python 3.12.6 en su versión "slim" (más ligera).
# *	**WORKDIR /app**: Establece el directorio de trabajo dentro del contenedor en /app.
# *	**RUN pip install ...**: Instala las dependencias necesarias. (Si tuviéramos un requirements.txt, sería más mantenible copiarlo y usar pip install -r requirements.txt. Aquí, por simplicidad, instalamos directamente los paquetes principales).
# *	**COPY . /app**: Copia todo el contenido de nuestro proyecto en la imagen (código de la API, modelo entrenado, etc., al directorio de trabajo).
# *	**EXPOSE 8000**: Documenta que el contenedor usará el puerto 8000 (esto no abre el puerto por sí mismo, pero es informativo para quien use la imagen).
# *	**CMD ...**: Define el comando que se ejecutará al iniciar el contenedor. Usamos Uvicorn para correr la aplicación FastAPI, vinculando a todas las interfaces 0.0.0.0 en el puerto 8000.

# %% [markdown]
# ## 5 Construcción de la imagen Docker
# ---
#
# Con el Dockerfile listo, procedemos a construir la **imagen Docker**. Normalmente, haríamos esto con el comando docker build. Le daremos un nombre a la imagen, por ejemplo student-performance-api y una etiqueta v1 (versión 1).

# %%
## Creación de la imagen
# !docker build -t student-performance-api:v1
# Out:
# /bin/bash: line 1: docker: command not found

# %% [markdown]
# ---
#
# Esto ejecutaría el contenedor en segundo plano (-d de detached) y mapearía el puerto 8000 del contenedor al puerto 8000 de la máquina host, de forma que la API sería accesible en http://localhost:8000.
#
# Sin embargo, en **Google Colab** no podemos correr directamente ese comando. Como mencionamos, usaremos udocker para ejecutar la imagen sin daemon Docker. udocker nos permite descargar y ejecutar imágenes Docker en modo usuario.

# %%
# Instalación de udocker en Colab
# !pip install -q udocker
# !udocker install
# Out:
# Error: do not run as root !

# %%
# %%bash
# UDOCKER_ALLOW_ROOT=1 udocker pull python:3.10-slim
# UDOCKER_ALLOW_ROOT=1 udocker run --publish=8000:8000 -v /content/proyecto_mlops_equipo_56:/app -w /app python:3.10-slim \
#     bash -c "pip install fastapi uvicorn pandas scikit-learn joblib && uvicorn app_api:app --host 0.0.0.0 --port 8000"
# Out:
# Error: do not run as root !
# Error: do not run as root !
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-3051688869.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'udocker pull python:3.10-slim  # descargar la imagen base si no está ya\nudocker run --publish=8000:8000 -v /content/proyecto_mlops_equipo_56:/app -w /app python:3.10-slim \\\n    bash -c "pip install fastapi uvicorn pandas scikit-learn joblib && uvicorn app_api:app --host 0.0.0.0 --port 8000"\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'udocker pull python:3.10-slim  # descargar la imagen base si no est\xc3\xa1 ya\nudocker run --publish=8000:8000 -v /content/proyecto_mlops_equipo_56:/app -w /app python:3.10-slim \\\n    bash -c "pip install fastapi uvicorn pandas scikit-learn joblib && uvicorn app_api:app --host 0.0.0.0 --port 8000"\n'' returned non-zero exit status 1.

# %% [markdown]
# # Despliegue en Docker desde Google Colab (Simulado con `udocker`)
#
# ## Limitaciones del entorno
# Google Colab **no permite ejecutar Docker directamente** ni cuenta con los recursos necesarios del sistema (como `dockerd`, `cgroups`, `namespaces`). Por esta razón, se intentó usar `udocker` para simular un contenedor sin privilegios, pero se encontró la siguiente limitación:
#
# ```
# Error: do not run as root!
# ```
#
# Esto ocurre porque Colab ya se ejecuta como `root`, lo cual `udocker` explícitamente bloquea.
#
# ---
#
# ## Qué se logró
# - Entrenamiento y validación del modelo.
# - Implementación completa de API con FastAPI y Uvicorn.
# - Generación del `Dockerfile` funcional.
# - Simulación parcial de ejecución con `udocker` (sin éxito por restricciones).
# - Documentación completa de los pasos necesarios para ejecutar el contenedor en una máquina con Docker real.
#
# ---
#
# ## Cómo se ejecutaría el contenedor (fuera de Colab)
# Una vez construido con:
#
# ```bash
# docker build -t student-performance-api:v1 .
# ```
#
# Se puede correr con:
#
# ```bash
# docker run -d -p 8000:8000 student-performance-api:v1
# ```
#
# Esto expondría la API en: [http://localhost:8000](http://localhost:8000)
#
# ---
#
# ## Consideraciones finales
#
# > Este notebook (`despliegue_docker.ipynb`) sirve como plantilla de despliegue documentado.
# > Un compañero del equipo podrá usarlo desde una máquina con Docker instalado para validar el contenedor, ya que la construcción y ejecución **no son posibles directamente en Colab**.
#
# Con los archivos generados (`Dockerfile`, `requirements.txt`, `app_api.py`) y esta documentación, se cumple con el objetivo de portabilidad y despliegue bajo las restricciones de entorno.
